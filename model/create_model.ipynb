# %% [markdown]
# # Create_Model.py 개요
# ## 1.1사용함수 정리
# * pandas : DataFrame 형식 및 연산
# * numpy : 기본 연산자
# * xgboost,lightgbm,extraTree,randomForest : stacking시 사용하는 1-level base 모델 및 2-level 모델
# * veckstack : stacking 함수
# * joblib : 모델 저장
# * sklearn : 변수 scaling
# * keras : 생존일 예측시 사용하는 신경망 모델.

# %%
# %pip install vecstack
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from vecstack import StackingTransformer
import joblib
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import keras.backend as K
from sklearn.pipeline import Pipeline
# Out:
# Requirement already satisfied: vecstack in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vecstack) (1.16.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from vecstack) (1.3.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from vecstack) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18->vecstack) (0.13.2)

# %% [markdown]
# ## 1.2 데이터 로드
# * 전처리 단계에서 사용한 데이터 로드
# * 데이터 불균형 해소를 위해 undersampling (이탈 vs 생존)

# %%
## train_preprocess 데이터 로드
data=  pd.read_csv('preprocess/train_preprocess_1.csv') 


## undersampling
data.loc[data['churn']==1].shape 
a_1 = data.loc[data['churn']==1]
a_0 = data.loc[data['churn']==0].sample(data.loc[data['churn']==1].shape [0])
b = pd.concat([a_1,a_0])

## input / label 분리
y_train = b[['acc_id','churn','churn_week','survival_time']]
x_train = b.iloc[:,6:]

# %% [markdown]
# ###  범주형 자료 encoding

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

def encoding_cate(x):

    x['pay_yn'] = x['pay_yn'].astype(object)
    x['most_trade_item'] = x['most_trade_item'].astype(object)
    x['most_trade_time'] = x['most_trade_time'].astype(object)

    print('There were {} columns before encoding categorical features'.format(x.shape[1]))
    combined = oneHotEncode(x, ['pay_yn','most_trade_time','most_trade_item'])
    print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
    return combined

## 범주형 함수 encoding 적용
train_combined = encoding_cate(x_train)
# Out:
# There were 129 columns before encoding categorical features
# There are 140 columns after encoding categorical features

# %% [markdown]
# ## 2.1 이탈 유무 binary 분류
# ### 2.1.1 stacking에 적용할 1-level 함수 사용
# * XGBoost, LightGBM, ExtraTree, RandomForest 를 기본함수로 stacking 첫번째 단계에 사용

# %%
xgb = XGBClassifier(max_depth=5, n_estimators=100, objective='reg:logistic')
lgbm = LGBMClassifier(max_depth=5,n_estimators=100, objective='binary',num_boost_round=10)
ext = ExtraTreesClassifier(n_estimators=100)
rf =  RandomForestClassifier(max_depth=5, n_estimators=100)


models = [('xgb',xgb),('lgbm',lgbm),('ext',ext),('rf',rf)]
stack= StackingTransformer(estimators = models, regression=False, n_folds=5,stratified=True, needs_proba= True,
       shuffle = True, verbose=2)
stack = stack.fit(train_combined, y_train.churn)
s_train = stack.transform(train_combined)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [log_loss]
# variant:      [A]
# n_estimators: [4]
#
# estimator  0: [xgb: XGBClassifier]
#     fold  0:  [0.48997722]
#     fold  1:  [0.49024277]
#     fold  2:  [0.49583155]
#     fold  3:  [0.50193583]
#     fold  4:  [0.48615832]
#     ----
#     MEAN:     [0.49282914] + [0.00550034]
#
# estimator  1: [lgbm: LGBMClassifier]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  0:  [0.56074173]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  1:  [0.56050706]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  2:  [0.56293608]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  3:  [0.56615312]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  4:  [0.56003864]
#     ----
#     MEAN:     [0.56207533] + [0.00226960]
#
# estimator  2: [ext: ExtraTreesClassifier]
#     fold  0:  [0.48251265]
#     fold  1:  [0.46923722]
#     fold  2:  [0.47633424]
#     fold  3:  [0.47334179]
#     fold  4:  [0.47254335]
#     ----
#     MEAN:     [0.47479385] + [0.00447218]
#
# estimator  3: [rf: RandomForestClassifier]
#     fold  0:  [0.53923080]
#     fold  1:  [0.53580899]
#     fold  2:  [0.54259671]
#     fold  3:  [0.54461350]
#     fold  4:  [0.53673624]
#     ----
#     MEAN:     [0.53979725] + [0.00336541]
#
# Train set was detected.
# Transforming...
#
# estimator  0: [xgb: XGBClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  1: [lgbm: LGBMClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  2: [ext: ExtraTreesClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  3: [rf: RandomForestClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE

# %% [markdown]
# ### 2.1.2 stacking 2-level 함수 실행.

# %%
churn_yn_model = XGBClassifier(max_depth=5, learning_rate=0.08, n_estimators=1000, objective = 'reg:logistic',nthread=4).fit(s_train, y_train.churn)

# %% [markdown]
# ### 2.1.3stacking 함수 저장

# %%
steps = [('stack', stack),
         ('final_estimator', churn_yn_model)]
pipe = Pipeline(steps)
pipe = pipe.set_params(stack__verbose=0)
_ = joblib.dump(pipe, 'model/churn_yn_model.pkl')

# %% [markdown]
# ## 2.2 생존일자 Multi-class 분류 & 회귀
# * 실제 이탈한 사람들만 학습데이터로 사용.

# %%
## 실제 이탈한 사람들을 대상으로 input을 구성
y_train = a_1[['acc_id','churn_week','survival_time']]
x_train = a_1.iloc[:,6:]

train_combined = encoding_cate(x_train)
# Out:
# There were 129 columns before encoding categorical features
# There are 140 columns after encoding categorical features

# %% [markdown]
# ### 2.2.1 multi-class 분류
# * 이탈 주차(1주~9주)를 분류하는 모델 학습

# %%
rg_xgb_model = XGBClassifier(max_depth= 5,nthread=4, learning_rate=0.08, objective= 'multi:softmax',n_estimators=1000,gamma=5).fit(train_combined, y_train.churn_week)

# %% [markdown]
# ### 2.2.2 신경망 회귀
# * 신경망으로 이탈날짜를 회귀모형으로 구성
# * 0~1 사이로 MinMax scaling을 input에 적용
# * loss함수는 실제 score function에서 사용하는, 날짜 오차에 대한 감소폭을 이용하여 구성

# %%
#def custom_loss(y_true,y_pred):
 # d = y_true-y_pred
  #score_max = 30
  #score = 30*K.exp(-(K.square(d)/450))
  #loss = score_max - score
  #return K.sum(loss)
  
scaler =MinMaxScaler()
scaler.fit(train_combined)
nn_x_train = scaler.transform(train_combined)
  
model_st = Sequential()
model_st.add(Dense(90,input_dim = 140 ,activation='relu'))
model_st.add(Dense(90, activation='relu'))
model_st.add(Dense(1))
model_st.compile(optimizer='Adam',
              loss= 'mean_squared_error',
              metrics=['mae'])

nn_model_st = model_st.fit(nn_x_train, y_train.survival_time, epochs=300, batch_size=10)
# Out:
# Epoch 1/300
# 18004/18004 [==============================] - 3s 143us/step - loss: 245.6395 - mean_absolute_error: 12.6483
# Epoch 2/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 231.3026 - mean_absolute_error: 12.2682
# Epoch 3/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 226.5631 - mean_absolute_error: 12.0721
# Epoch 4/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 223.2437 - mean_absolute_error: 11.9184
# Epoch 5/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 220.4710 - mean_absolute_error: 11.8050
# Epoch 6/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 217.5885 - mean_absolute_error: 11.7033
# Epoch 7/300
# 18004/18004 [==============================] - 2s 135us/step - loss: 215.7483 - mean_absolute_error: 11.6105
# Epoch 8/300
# 18004/18004 [==============================] - 3s 141us/step - loss: 213.4499 - mean_absolute_error: 11.5326
# Epoch 9/300
# 18004/18004 [==============================] - 2s 137us/step - loss: 211.5449 - mean_absolute_error: 11.4570
# Epoch 10/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 209.4971 - mean_absolute_error: 11.3769
# Epoch 11/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 207.9906 - mean_absolute_error: 11.3167
# Epoch 12/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 206.8175 - mean_absolute_error: 11.2698
# Epoch 13/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 205.4099 - mean_absolute_error: 11.2358
# Epoch 14/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 203.6455 - mean_absolute_error: 11.1767
# Epoch 15/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 201.7524 - mean_absolute_error: 11.1051
# Epoch 16/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 200.9042 - mean_absolute_error: 11.0755
# Epoch 17/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 199.4717 - mean_absolute_error: 11.0214
# Epoch 18/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 198.0874 - mean_absolute_error: 10.9770
# Epoch 19/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 196.6834 - mean_absolute_error: 10.9321
# Epoch 20/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 196.0895 - mean_absolute_error: 10.9077
# Epoch 21/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 194.8285 - mean_absolute_error: 10.8564
# Epoch 22/300
# 18004/18004 [==============================] - 2s 124us/step - loss: 193.5681 - mean_absolute_error: 10.8047
# Epoch 23/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 192.1414 - mean_absolute_error: 10.7728
# Epoch 24/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 192.5316 - mean_absolute_error: 10.7499
# Epoch 25/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 190.1847 - mean_absolute_error: 10.6889
# Epoch 26/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 189.1801 - mean_absolute_error: 10.6399
# Epoch 27/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 188.5669 - mean_absolute_error: 10.6256
# Epoch 28/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 186.9640 - mean_absolute_error: 10.5649
# Epoch 29/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 185.8832 - mean_absolute_error: 10.5340
# Epoch 30/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 185.1984 - mean_absolute_error: 10.5177
# Epoch 31/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 184.8039 - mean_absolute_error: 10.4934
# Epoch 32/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 183.0223 - mean_absolute_error: 10.4528
# Epoch 33/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 181.7992 - mean_absolute_error: 10.4055
# Epoch 34/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 180.7821 - mean_absolute_error: 10.3661
# Epoch 35/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 179.5092 - mean_absolute_error: 10.3210
# Epoch 36/300
# 18004/18004 [==============================] - 2s 132us/step - loss: 178.3071 - mean_absolute_error: 10.2766
# Epoch 37/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 177.6068 - mean_absolute_error: 10.2639
# Epoch 38/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 176.6776 - mean_absolute_error: 10.2302
# Epoch 39/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 175.7087 - mean_absolute_error: 10.2055
# Epoch 40/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 173.6802 - mean_absolute_error: 10.1288
# Epoch 41/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 172.7150 - mean_absolute_error: 10.0892
# Epoch 42/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 172.4861 - mean_absolute_error: 10.0848
# Epoch 43/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 171.8158 - mean_absolute_error: 10.0752
# Epoch 44/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 170.2821 - mean_absolute_error: 9.9979
# Epoch 45/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 170.1683 - mean_absolute_error: 10.0228
# Epoch 46/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 168.8602 - mean_absolute_error: 9.9612
# Epoch 47/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 167.1276 - mean_absolute_error: 9.9067
# Epoch 48/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 166.7744 - mean_absolute_error: 9.8820
# Epoch 49/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 165.8216 - mean_absolute_error: 9.8799
# Epoch 50/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 164.6276 - mean_absolute_error: 9.8160
# Epoch 51/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 164.0247 - mean_absolute_error: 9.7863
# Epoch 52/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 162.7576 - mean_absolute_error: 9.7732
# Epoch 53/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 162.0060 - mean_absolute_error: 9.7328
# Epoch 54/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 160.9502 - mean_absolute_error: 9.7088
# Epoch 55/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 159.8885 - mean_absolute_error: 9.6611
# Epoch 56/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 159.4128 - mean_absolute_error: 9.6563
# Epoch 57/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 157.5429 - mean_absolute_error: 9.5728
# Epoch 58/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 157.5638 - mean_absolute_error: 9.5811
# Epoch 59/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 156.2065 - mean_absolute_error: 9.5278
# Epoch 60/300
# 18004/18004 [==============================] - 2s 131us/step - loss: 155.9390 - mean_absolute_error: 9.5036
# Epoch 61/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 154.6171 - mean_absolute_error: 9.4825
# Epoch 62/300
# 18004/18004 [==============================] - 2s 133us/step - loss: 154.0987 - mean_absolute_error: 9.4550
# Epoch 63/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 153.2334 - mean_absolute_error: 9.4393
# Epoch 64/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 152.4521 - mean_absolute_error: 9.4061
# Epoch 65/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 151.0807 - mean_absolute_error: 9.3442
# Epoch 66/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 151.1325 - mean_absolute_error: 9.3446
# Epoch 67/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 149.7766 - mean_absolute_error: 9.3029
# Epoch 68/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 149.3686 - mean_absolute_error: 9.2840
# Epoch 69/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 148.8687 - mean_absolute_error: 9.2664
# Epoch 70/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 148.0421 - mean_absolute_error: 9.2406
# Epoch 71/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 146.7632 - mean_absolute_error: 9.2092
# Epoch 72/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 146.9509 - mean_absolute_error: 9.2046
# Epoch 73/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 145.5593 - mean_absolute_error: 9.1413
# Epoch 74/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 144.4000 - mean_absolute_error: 9.1158
# Epoch 75/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 144.9481 - mean_absolute_error: 9.1336
# Epoch 76/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 142.9936 - mean_absolute_error: 9.0636
# Epoch 77/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 142.2892 - mean_absolute_error: 9.0603
# Epoch 78/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 142.2505 - mean_absolute_error: 9.0409
# Epoch 79/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 140.9221 - mean_absolute_error: 8.9746
# Epoch 80/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 140.1864 - mean_absolute_error: 8.9499
# Epoch 81/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 139.4570 - mean_absolute_error: 8.9387
# Epoch 82/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 139.0487 - mean_absolute_error: 8.9119
# Epoch 83/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 138.7586 - mean_absolute_error: 8.8937
# Epoch 84/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 138.1083 - mean_absolute_error: 8.8784
# Epoch 85/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 137.0145 - mean_absolute_error: 8.8251
# Epoch 86/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 135.9718 - mean_absolute_error: 8.7964
# Epoch 87/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 134.9913 - mean_absolute_error: 8.7735
# Epoch 88/300
# 18004/18004 [==============================] - 2s 138us/step - loss: 134.7831 - mean_absolute_error: 8.7617
# Epoch 89/300
# 18004/18004 [==============================] - 2s 137us/step - loss: 134.5733 - mean_absolute_error: 8.7333
# Epoch 90/300
# 18004/18004 [==============================] - 2s 139us/step - loss: 133.5757 - mean_absolute_error: 8.7087
# Epoch 91/300
# 18004/18004 [==============================] - 2s 134us/step - loss: 132.8363 - mean_absolute_error: 8.6887
# Epoch 92/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 132.4916 - mean_absolute_error: 8.6730
# Epoch 93/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 131.1149 - mean_absolute_error: 8.6152
# Epoch 94/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 130.6621 - mean_absolute_error: 8.6180
# Epoch 95/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 130.5734 - mean_absolute_error: 8.6025
# Epoch 96/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 129.5535 - mean_absolute_error: 8.5630
# Epoch 97/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 129.0840 - mean_absolute_error: 8.5337
# Epoch 98/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 128.8989 - mean_absolute_error: 8.5501
# Epoch 99/300
# 18004/18004 [==============================] - 2s 124us/step - loss: 127.9551 - mean_absolute_error: 8.5028
# Epoch 100/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 127.3377 - mean_absolute_error: 8.4671
# Epoch 101/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 126.5209 - mean_absolute_error: 8.4599
# Epoch 102/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 125.7125 - mean_absolute_error: 8.4164
# Epoch 103/300
# 18004/18004 [==============================] - 2s 138us/step - loss: 125.2584 - mean_absolute_error: 8.4023
# Epoch 104/300
# 18004/18004 [==============================] - 3s 168us/step - loss: 124.9207 - mean_absolute_error: 8.3766
# Epoch 105/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 124.8690 - mean_absolute_error: 8.3830
# Epoch 106/300
# 18004/18004 [==============================] - 3s 166us/step - loss: 123.6637 - mean_absolute_error: 8.3272
# Epoch 107/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 123.9866 - mean_absolute_error: 8.3456
# Epoch 108/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 122.4196 - mean_absolute_error: 8.3037
# Epoch 109/300
# 18004/18004 [==============================] - 3s 156us/step - loss: 121.7095 - mean_absolute_error: 8.2598
# Epoch 110/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 121.3516 - mean_absolute_error: 8.2494
# Epoch 111/300
# 18004/18004 [==============================] - 3s 165us/step - loss: 121.8611 - mean_absolute_error: 8.2487
# Epoch 112/300
# 18004/18004 [==============================] - 3s 165us/step - loss: 119.3017 - mean_absolute_error: 8.1810
# Epoch 113/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 119.8794 - mean_absolute_error: 8.1883
# Epoch 114/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 119.7604 - mean_absolute_error: 8.2010
# Epoch 115/300
# 18004/18004 [==============================] - 3s 166us/step - loss: 119.3595 - mean_absolute_error: 8.1721
# Epoch 116/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 117.9174 - mean_absolute_error: 8.1236
# Epoch 117/300
# 18004/18004 [==============================] - 3s 166us/step - loss: 117.6790 - mean_absolute_error: 8.1149
# Epoch 118/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 117.0322 - mean_absolute_error: 8.0968
# Epoch 119/300
# 18004/18004 [==============================] - 3s 166us/step - loss: 116.2520 - mean_absolute_error: 8.0542
# Epoch 120/300
# 18004/18004 [==============================] - 3s 157us/step - loss: 116.0155 - mean_absolute_error: 8.0506
# Epoch 121/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 116.1383 - mean_absolute_error: 8.0405
# Epoch 122/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 115.6093 - mean_absolute_error: 8.0379
# Epoch 123/300
# 18004/18004 [==============================] - 3s 158us/step - loss: 113.5245 - mean_absolute_error: 7.9474
# Epoch 124/300
# 18004/18004 [==============================] - 3s 167us/step - loss: 114.3762 - mean_absolute_error: 7.9832
# Epoch 125/300
# 18004/18004 [==============================] - 3s 155us/step - loss: 113.5503 - mean_absolute_error: 7.9548
# Epoch 126/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 113.1673 - mean_absolute_error: 7.9461
# Epoch 127/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 113.0331 - mean_absolute_error: 7.9381
# Epoch 128/300
# 18004/18004 [==============================] - 3s 158us/step - loss: 111.9996 - mean_absolute_error: 7.9088
# Epoch 129/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 111.7582 - mean_absolute_error: 7.8903
# Epoch 130/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 112.0611 - mean_absolute_error: 7.8924
# Epoch 131/300
# 18004/18004 [==============================] - 3s 162us/step - loss: 111.1417 - mean_absolute_error: 7.8507
# Epoch 132/300
# 18004/18004 [==============================] - 3s 154us/step - loss: 110.7032 - mean_absolute_error: 7.8445
# Epoch 133/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 110.3771 - mean_absolute_error: 7.8322
# Epoch 134/300
# 18004/18004 [==============================] - 3s 155us/step - loss: 109.5353 - mean_absolute_error: 7.8081
# Epoch 135/300
# 18004/18004 [==============================] - 3s 155us/step - loss: 108.7716 - mean_absolute_error: 7.7701
# Epoch 136/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 108.8728 - mean_absolute_error: 7.7843
# Epoch 137/300
# 18004/18004 [==============================] - 3s 153us/step - loss: 108.1166 - mean_absolute_error: 7.7441
# Epoch 138/300
# 18004/18004 [==============================] - 3s 156us/step - loss: 108.1130 - mean_absolute_error: 7.7310
# Epoch 139/300
# 18004/18004 [==============================] - 3s 156us/step - loss: 107.5666 - mean_absolute_error: 7.7416
# Epoch 140/300
# 18004/18004 [==============================] - 3s 155us/step - loss: 106.9729 - mean_absolute_error: 7.7020
# Epoch 141/300
# 18004/18004 [==============================] - 3s 152us/step - loss: 106.0153 - mean_absolute_error: 7.6441
# Epoch 142/300
# 18004/18004 [==============================] - 3s 153us/step - loss: 106.8408 - mean_absolute_error: 7.6875
# Epoch 143/300
# 18004/18004 [==============================] - 3s 152us/step - loss: 106.0157 - mean_absolute_error: 7.6625
# Epoch 144/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 106.1579 - mean_absolute_error: 7.6540
# Epoch 145/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 105.6995 - mean_absolute_error: 7.6273
# Epoch 146/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 104.7903 - mean_absolute_error: 7.6015
# Epoch 147/300
# 18004/18004 [==============================] - 3s 167us/step - loss: 104.7225 - mean_absolute_error: 7.6004
# Epoch 148/300
# 18004/18004 [==============================] - 3s 165us/step - loss: 104.9450 - mean_absolute_error: 7.5948
# Epoch 149/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 103.4116 - mean_absolute_error: 7.5472
# Epoch 150/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 103.2919 - mean_absolute_error: 7.5573
# Epoch 151/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 102.6121 - mean_absolute_error: 7.4976
# Epoch 152/300
# 18004/18004 [==============================] - 3s 151us/step - loss: 102.9437 - mean_absolute_error: 7.5217
# Epoch 153/300
# 18004/18004 [==============================] - 3s 156us/step - loss: 102.7081 - mean_absolute_error: 7.5049
# Epoch 154/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 102.4824 - mean_absolute_error: 7.5087
# Epoch 155/300
# 18004/18004 [==============================] - 3s 158us/step - loss: 102.0323 - mean_absolute_error: 7.5067
# Epoch 156/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 101.1776 - mean_absolute_error: 7.4624
# Epoch 157/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 100.9664 - mean_absolute_error: 7.4442
# Epoch 158/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 100.9672 - mean_absolute_error: 7.4439
# Epoch 159/300
# 18004/18004 [==============================] - 3s 165us/step - loss: 99.7030 - mean_absolute_error: 7.4002
# Epoch 160/300
# 18004/18004 [==============================] - 3s 157us/step - loss: 100.0254 - mean_absolute_error: 7.3990
# Epoch 161/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 99.5993 - mean_absolute_error: 7.3935
# Epoch 162/300
# 18004/18004 [==============================] - 3s 152us/step - loss: 99.1525 - mean_absolute_error: 7.3601
# Epoch 163/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 99.2805 - mean_absolute_error: 7.3817
# Epoch 164/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 97.8697 - mean_absolute_error: 7.3166
# Epoch 165/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 98.0455 - mean_absolute_error: 7.3392
# Epoch 166/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 97.2757 - mean_absolute_error: 7.2999
# Epoch 167/300
# 18004/18004 [==============================] - 3s 162us/step - loss: 97.0736 - mean_absolute_error: 7.2822
# Epoch 168/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 97.4608 - mean_absolute_error: 7.3205
# Epoch 169/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 96.9843 - mean_absolute_error: 7.2976
# Epoch 170/300
# 18004/18004 [==============================] - 3s 158us/step - loss: 96.0846 - mean_absolute_error: 7.2365
# Epoch 171/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 96.2361 - mean_absolute_error: 7.2401
# Epoch 172/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 96.2766 - mean_absolute_error: 7.2620
# Epoch 173/300
# 18004/18004 [==============================] - 3s 157us/step - loss: 95.7589 - mean_absolute_error: 7.2540
# Epoch 174/300
# 18004/18004 [==============================] - 3s 166us/step - loss: 95.1090 - mean_absolute_error: 7.2039
# Epoch 175/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 94.7029 - mean_absolute_error: 7.1834
# Epoch 176/300
# 18004/18004 [==============================] - 3s 162us/step - loss: 94.4065 - mean_absolute_error: 7.1671
# Epoch 177/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 94.2087 - mean_absolute_error: 7.1722
# Epoch 178/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 93.7949 - mean_absolute_error: 7.1464
# Epoch 179/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 94.4470 - mean_absolute_error: 7.1882
# Epoch 180/300
# 18004/18004 [==============================] - 3s 153us/step - loss: 92.9221 - mean_absolute_error: 7.1148
# Epoch 181/300
# 18004/18004 [==============================] - 3s 143us/step - loss: 93.3293 - mean_absolute_error: 7.1155
# Epoch 182/300
# 18004/18004 [==============================] - 3s 154us/step - loss: 92.9678 - mean_absolute_error: 7.1245
# Epoch 183/300
# 18004/18004 [==============================] - 3s 159us/step - loss: 92.4669 - mean_absolute_error: 7.0927
# Epoch 184/300
# 18004/18004 [==============================] - 3s 150us/step - loss: 92.6488 - mean_absolute_error: 7.0947
# Epoch 185/300
# 18004/18004 [==============================] - 3s 163us/step - loss: 91.8637 - mean_absolute_error: 7.0821
# Epoch 186/300
# 18004/18004 [==============================] - 3s 167us/step - loss: 91.7808 - mean_absolute_error: 7.0664
# Epoch 187/300
# 18004/18004 [==============================] - 3s 168us/step - loss: 90.9269 - mean_absolute_error: 7.0160
# Epoch 188/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 91.2080 - mean_absolute_error: 7.0386
# Epoch 189/300
# 18004/18004 [==============================] - 3s 157us/step - loss: 90.7565 - mean_absolute_error: 7.0124
# Epoch 190/300
# 18004/18004 [==============================] - 3s 160us/step - loss: 89.9043 - mean_absolute_error: 7.0096
# Epoch 191/300
# 18004/18004 [==============================] - 3s 174us/step - loss: 90.5990 - mean_absolute_error: 7.0033
# Epoch 192/300
# 18004/18004 [==============================] - 3s 149us/step - loss: 89.8264 - mean_absolute_error: 6.9859
# Epoch 193/300
# 18004/18004 [==============================] - 3s 161us/step - loss: 89.4620 - mean_absolute_error: 6.9684
# Epoch 194/300
# 18004/18004 [==============================] - 3s 150us/step - loss: 89.3786 - mean_absolute_error: 6.9815
# Epoch 195/300
# 18004/18004 [==============================] - 3s 156us/step - loss: 89.9408 - mean_absolute_error: 6.9837
# Epoch 196/300
# 18004/18004 [==============================] - 3s 168us/step - loss: 88.3073 - mean_absolute_error: 6.9116
# Epoch 197/300
# 18004/18004 [==============================] - 3s 154us/step - loss: 89.1734 - mean_absolute_error: 6.9549
# Epoch 198/300
# 18004/18004 [==============================] - 3s 162us/step - loss: 88.4372 - mean_absolute_error: 6.9346
# Epoch 199/300
# 18004/18004 [==============================] - 3s 164us/step - loss: 87.7022 - mean_absolute_error: 6.8964
# Epoch 200/300
# 18004/18004 [==============================] - 3s 169us/step - loss: 87.8552 - mean_absolute_error: 6.8847
# Epoch 201/300
# 18004/18004 [==============================] - 4s 206us/step - loss: 87.6348 - mean_absolute_error: 6.8983
# Epoch 202/300
# 18004/18004 [==============================] - 3s 191us/step - loss: 87.2910 - mean_absolute_error: 6.8784
# Epoch 203/300
# 18004/18004 [==============================] - 4s 202us/step - loss: 86.5905 - mean_absolute_error: 6.8457
# Epoch 204/300
# 18004/18004 [==============================] - 4s 206us/step - loss: 86.6971 - mean_absolute_error: 6.8668
# Epoch 205/300
# 18004/18004 [==============================] - 3s 192us/step - loss: 86.9232 - mean_absolute_error: 6.8483
# Epoch 206/300
# 18004/18004 [==============================] - 4s 199us/step - loss: 86.2125 - mean_absolute_error: 6.8390
# Epoch 207/300
# 18004/18004 [==============================] - 4s 208us/step - loss: 86.0606 - mean_absolute_error: 6.8419
# Epoch 208/300
# 18004/18004 [==============================] - 3s 194us/step - loss: 86.0305 - mean_absolute_error: 6.8258
# Epoch 209/300
# 18004/18004 [==============================] - 4s 211us/step - loss: 85.1084 - mean_absolute_error: 6.7876
# Epoch 210/300
# 18004/18004 [==============================] - 4s 219us/step - loss: 85.5903 - mean_absolute_error: 6.8162
# Epoch 211/300
# 18004/18004 [==============================] - 4s 212us/step - loss: 85.4131 - mean_absolute_error: 6.8176
# Epoch 212/300
# 18004/18004 [==============================] - 3s 174us/step - loss: 84.9449 - mean_absolute_error: 6.7776
# Epoch 213/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 85.4512 - mean_absolute_error: 6.8142
# Epoch 214/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 84.6617 - mean_absolute_error: 6.7747
# Epoch 215/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 84.1328 - mean_absolute_error: 6.7438
# Epoch 216/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 83.8773 - mean_absolute_error: 6.7345
# Epoch 217/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 83.8197 - mean_absolute_error: 6.7374
# Epoch 218/300
# 18004/18004 [==============================] - 2s 122us/step - loss: 83.7622 - mean_absolute_error: 6.7174
# Epoch 219/300
# 18004/18004 [==============================] - 2s 122us/step - loss: 82.5196 - mean_absolute_error: 6.6880
# Epoch 220/300
# 18004/18004 [==============================] - 2s 120us/step - loss: 82.8837 - mean_absolute_error: 6.7153
# Epoch 221/300
# 18004/18004 [==============================] - 2s 122us/step - loss: 83.9219 - mean_absolute_error: 6.7320
# Epoch 222/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 82.5565 - mean_absolute_error: 6.7031
# Epoch 223/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 82.4109 - mean_absolute_error: 6.6704
# Epoch 224/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 81.8163 - mean_absolute_error: 6.6391
# Epoch 225/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 81.8618 - mean_absolute_error: 6.6476
# Epoch 226/300
# 18004/18004 [==============================] - 2s 124us/step - loss: 82.2202 - mean_absolute_error: 6.6531
# Epoch 227/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 81.5087 - mean_absolute_error: 6.6507
# Epoch 228/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 81.6308 - mean_absolute_error: 6.6489
# Epoch 229/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 81.0216 - mean_absolute_error: 6.6232
# Epoch 230/300
# 18004/18004 [==============================] - 2s 120us/step - loss: 80.5063 - mean_absolute_error: 6.6178
# Epoch 231/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 80.7811 - mean_absolute_error: 6.6113
# Epoch 232/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 80.6581 - mean_absolute_error: 6.6007
# Epoch 233/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 80.2400 - mean_absolute_error: 6.5817
# Epoch 234/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 80.6593 - mean_absolute_error: 6.6041
# Epoch 235/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 80.0070 - mean_absolute_error: 6.5756
# Epoch 236/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 79.7715 - mean_absolute_error: 6.5533
# Epoch 237/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 79.2109 - mean_absolute_error: 6.5163
# Epoch 238/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 79.3807 - mean_absolute_error: 6.5492
# Epoch 239/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 78.9535 - mean_absolute_error: 6.5358
# Epoch 240/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 79.0359 - mean_absolute_error: 6.5408
# Epoch 241/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 78.5758 - mean_absolute_error: 6.5085
# Epoch 242/300
# 18004/18004 [==============================] - 2s 135us/step - loss: 78.9569 - mean_absolute_error: 6.5157
# Epoch 243/300
# 18004/18004 [==============================] - 3s 139us/step - loss: 78.4838 - mean_absolute_error: 6.4989
# Epoch 244/300
# 18004/18004 [==============================] - 2s 136us/step - loss: 78.6265 - mean_absolute_error: 6.5101
# Epoch 245/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 77.8546 - mean_absolute_error: 6.4678
# Epoch 246/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 77.8524 - mean_absolute_error: 6.4692
# Epoch 247/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 77.7176 - mean_absolute_error: 6.4800
# Epoch 248/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 77.4873 - mean_absolute_error: 6.4745
# Epoch 249/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 77.0885 - mean_absolute_error: 6.4384
# Epoch 250/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 77.0363 - mean_absolute_error: 6.4268
# Epoch 251/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 76.8289 - mean_absolute_error: 6.4436
# Epoch 252/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 76.7692 - mean_absolute_error: 6.4371
# Epoch 253/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 76.2182 - mean_absolute_error: 6.4164
# Epoch 254/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 76.6507 - mean_absolute_error: 6.4344
# Epoch 255/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 76.1583 - mean_absolute_error: 6.4154
# Epoch 256/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 76.2917 - mean_absolute_error: 6.3908
# Epoch 257/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 75.4695 - mean_absolute_error: 6.3813
# Epoch 258/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 75.8349 - mean_absolute_error: 6.3875
# Epoch 259/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 75.7238 - mean_absolute_error: 6.3966
# Epoch 260/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 75.3097 - mean_absolute_error: 6.3808
# Epoch 261/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 75.4308 - mean_absolute_error: 6.3489
# Epoch 262/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 75.5184 - mean_absolute_error: 6.3685
# Epoch 263/300
# 18004/18004 [==============================] - 2s 130us/step - loss: 75.1347 - mean_absolute_error: 6.3657
# Epoch 264/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 74.4402 - mean_absolute_error: 6.3254
# Epoch 265/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 74.7684 - mean_absolute_error: 6.3320
# Epoch 266/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 74.3665 - mean_absolute_error: 6.3159
# Epoch 267/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 73.9327 - mean_absolute_error: 6.2961
# Epoch 268/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 73.5116 - mean_absolute_error: 6.2947
# Epoch 269/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 73.9907 - mean_absolute_error: 6.3123
# Epoch 270/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 73.3102 - mean_absolute_error: 6.2655
# Epoch 271/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 73.7997 - mean_absolute_error: 6.2975
# Epoch 272/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 73.6910 - mean_absolute_error: 6.2916
# Epoch 273/300
# 18004/18004 [==============================] - 2s 123us/step - loss: 73.2562 - mean_absolute_error: 6.2767
# Epoch 274/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 73.1601 - mean_absolute_error: 6.2817
# Epoch 275/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 72.2053 - mean_absolute_error: 6.2360
# Epoch 276/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 72.8151 - mean_absolute_error: 6.2498
# Epoch 277/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 72.0757 - mean_absolute_error: 6.2095
# Epoch 278/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 72.1352 - mean_absolute_error: 6.2096
# Epoch 279/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 72.4264 - mean_absolute_error: 6.2261
# Epoch 280/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 72.1642 - mean_absolute_error: 6.2282
# Epoch 281/300
# 18004/18004 [==============================] - 2s 129us/step - loss: 72.3871 - mean_absolute_error: 6.2487
# Epoch 282/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 71.6761 - mean_absolute_error: 6.1957
# Epoch 283/300
# 18004/18004 [==============================] - 2s 122us/step - loss: 72.3610 - mean_absolute_error: 6.2148
# Epoch 284/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 71.4789 - mean_absolute_error: 6.1815
# Epoch 285/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 71.2700 - mean_absolute_error: 6.1833
# Epoch 286/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 71.2906 - mean_absolute_error: 6.1923
# Epoch 287/300
# 18004/18004 [==============================] - 2s 124us/step - loss: 70.7656 - mean_absolute_error: 6.1624
# Epoch 288/300
# 18004/18004 [==============================] - 2s 121us/step - loss: 70.8149 - mean_absolute_error: 6.1840
# Epoch 289/300
# 18004/18004 [==============================] - 2s 127us/step - loss: 70.6117 - mean_absolute_error: 6.1499
# Epoch 290/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 71.1403 - mean_absolute_error: 6.1692
# Epoch 291/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 70.6717 - mean_absolute_error: 6.1512
# Epoch 292/300
# 18004/18004 [==============================] - 2s 128us/step - loss: 69.9628 - mean_absolute_error: 6.1287
# Epoch 293/300
# 18004/18004 [==============================] - 2s 126us/step - loss: 70.1571 - mean_absolute_error: 6.1219
# Epoch 294/300
# 18004/18004 [==============================] - 2s 119us/step - loss: 70.4094 - mean_absolute_error: 6.1311
# Epoch 295/300
# 18004/18004 [==============================] - 2s 120us/step - loss: 69.6348 - mean_absolute_error: 6.1021
# Epoch 296/300
# 18004/18004 [==============================] - 2s 119us/step - loss: 70.0776 - mean_absolute_error: 6.1296
# Epoch 297/300
# 18004/18004 [==============================] - 2s 119us/step - loss: 69.4846 - mean_absolute_error: 6.1127
# Epoch 298/300
# 18004/18004 [==============================] - 2s 122us/step - loss: 69.6755 - mean_absolute_error: 6.1149
# Epoch 299/300
# 18004/18004 [==============================] - 2s 125us/step - loss: 70.3943 - mean_absolute_error: 6.1335
# Epoch 300/300
# 18004/18004 [==============================] - 2s 120us/step - loss: 69.1352 - mean_absolute_error: 6.0768

# %% [markdown]
# ### 2.2.3 모델 저장
# * 학습된 모델 저장.

# %%
import joblib
filename1 = 'model/churn_rg_model_1.sav'
joblib.dump(rg_xgb_model, filename1)

filename2 = 'model/churn_rg_model_2.sav'
joblib.dump(model_st, filename2)
# Out:
# ['/content/drive/My Drive/churn_rg_model_2_mse.sav']

# %% [markdown]
# # 3. 과금 모형 구성.
# ## 3.1과금유무 binary 모델 생성
# * 데이터의 불균형 해소를 위한 undersampling (과금 vs 비과금)

# %%
a_1 = data.loc[data['label_spent']==1].sample(data.loc[data['label_spent']==0].shape[0])
a_0 = data.loc[data['label_spent']==0]
b = pd.concat([a_1,a_0])

#%% label / input 분리
y_train = b[['acc_id','label_spent','amount_spent','survival_time']]
x_train = b.iloc[:,6:]

# %% [markdown]
# * 범주형 변수 encoding
# * 과금 예측시에는 survival_time을 변수로 사용.

# %%
train_combined = encoding_cate(x_train)
train_combined['survival_time'] = y_train['survival_time']
# Out:
# There were 129 columns before encoding categorical features
# There are 140 columns after encoding categorical features

# %% [markdown]
# ### 3.1.1 stacking에 적용할 1-level 함수 사용
# * XGBoost, LightGBM, ExtraTree, RandomForest 를 기본함수로 stacking 첫번째 단계에 사용

# %%
models = [('xrg' ,XGBClassifier(max_depth=5, n_estimators=100, objective='reg:logistic')),
       ('lgbm',LGBMClassifier(max_depth=5,n_estimators=100, objective='binary',num_boost_round=10)),
       ('ext', ExtraTreesClassifier(n_estimators=100)),
       ('rf', RandomForestClassifier(max_depth=5, n_estimators=100)) ]

stack= StackingTransformer(estimators = models, regression=False, n_folds=5,stratified=True, needs_proba= True,
       shuffle = True, verbose=2)
stack = stack.fit(train_combined, y_train.label_spent)
s_train = stack.transform(train_combined)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [log_loss]
# variant:      [A]
# n_estimators: [4]
#
# estimator  0: [xrg: XGBClassifier]
#     fold  0:  [0.32471779]
#     fold  1:  [0.30348733]
#     fold  2:  [0.32839493]
#     fold  3:  [0.31110876]
#     fold  4:  [0.31700718]
#     ----
#     MEAN:     [0.31694320] + [0.00901878]
#
# estimator  1: [lgbm: LGBMClassifier]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  0:  [0.42345955]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  1:  [0.41603846]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  2:  [0.43077548]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  3:  [0.42107366]
# /usr/local/lib/python3.6/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
#     fold  4:  [0.42226754]
#     ----
#     MEAN:     [0.42272294] + [0.00475386]
#
# estimator  2: [ext: ExtraTreesClassifier]
#     fold  0:  [0.40037844]
#     fold  1:  [0.33023435]
#     fold  2:  [0.36050331]
#     fold  3:  [0.35145404]
#     fold  4:  [0.34701353]
#     ----
#     MEAN:     [0.35791673] + [0.02339508]
#
# estimator  3: [rf: RandomForestClassifier]
#     fold  0:  [0.38289725]
#     fold  1:  [0.37066163]
#     fold  2:  [0.39117292]
#     fold  3:  [0.38396551]
#     fold  4:  [0.38629735]
#     ----
#     MEAN:     [0.38299893] + [0.00679481]
#
# Train set was detected.
# Transforming...
#
# estimator  0: [xrg: XGBClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  1: [lgbm: LGBMClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  2: [ext: ExtraTreesClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE
#
# estimator  3: [rf: RandomForestClassifier]
#     model from fold  0: done
#     model from fold  1: done
#     model from fold  2: done
#     model from fold  3: done
#     model from fold  4: done
#     ----
#     DONE

# %% [markdown]
# ### 3.1.2 stacking 2-level 함수 실행.

# %%
spend_yn_model = XGBClassifier(max_depth=5, learning_rate=0.08, n_estimators=1000, objective = 'reg:logistic',nthread=4).fit(s_train, y_train.label_spent)

# %% [markdown]
# ### 3.1.3 과금 유무 모델 저장

# %%
steps = [('stack', stack),
         ('final_estimator', spend_yn_model)]
pipe = Pipeline(steps)
_ = joblib.dump(pipe, 'model/spend_yn_model.pkl')

# %% [markdown]
# ## 3.2 과금 회귀 모형 구성

# %%
y_train = a_1[['acc_id','label_spent','amount_spent','survival_time']]
x_train = a_1.iloc[:,6:]

train_combined = encoding_cate(x_train)
train_combined['survival_time'] = y_train['survival_time']
# Out:
# There were 129 columns before encoding categorical features
# There are 140 columns after encoding categorical features

# %% [markdown]
# ### 3.2.1 신경망 학습
# * custom-loss 함수 적용. 과소평가시 loss가 더 큰 비대칭적인 loss함수.

# %%
def custom_loss(y_true,y_pred):
    d = y_true-y_pred
    bool_idx_1 = K.greater(d,0)
    score_max = (20*y_true) - 0.3*y_true
    score_under= (((10/9)*(y_pred/y_true)-1/9)*20*y_true) - 0.3*y_pred
    score_over = (20*y_true) - 0.3*y_pred
    loss1 = score_max - score_under
    loss2 = score_max - score_over
    loss = K.switch(bool_idx_1,loss1,loss2)
    return K.sum(loss)

scaler =MinMaxScaler()
scaler.fit(train_combined)
nn_x_train = scaler.transform(train_combined)

model_as = Sequential()
model_as.add(Dense(100, input_dim=141, activation='relu'))
model_as.add(Dense(100, activation='relu'))
model_as.add(Dense(1))
model_as.compile(optimizer='adam',
              loss=custom_loss, 
              metrics=['mae'])
model_as.summary()

nn_model = model_as.fit(nn_x_train, y_train.amount_spent, epochs=150, batch_size=10)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 100)               14200
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 24,401
# Trainable params: 24,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 16438/16438 [==============================] - 3s 174us/step - loss: 11.2484 - mean_absolute_error: 1.2100
# Epoch 2/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 6.8027 - mean_absolute_error: 1.1845
# Epoch 3/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 5.5310 - mean_absolute_error: 1.0925
# Epoch 4/150
# 16438/16438 [==============================] - 2s 150us/step - loss: 5.0208 - mean_absolute_error: 1.0594
# Epoch 5/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 4.5633 - mean_absolute_error: 1.0395
# Epoch 6/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 4.7384 - mean_absolute_error: 1.0476
# Epoch 7/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 4.0635 - mean_absolute_error: 1.0092
# Epoch 8/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 3.7701 - mean_absolute_error: 0.9639
# Epoch 9/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 3.9258 - mean_absolute_error: 1.0105
# Epoch 10/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 3.5064 - mean_absolute_error: 0.8960
# Epoch 11/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 3.7715 - mean_absolute_error: 0.9073
# Epoch 12/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 3.7603 - mean_absolute_error: 0.9123
# Epoch 13/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 3.3459 - mean_absolute_error: 0.8987
# Epoch 14/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 3.3916 - mean_absolute_error: 0.9000
# Epoch 15/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 3.4106 - mean_absolute_error: 0.8707
# Epoch 16/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 3.3499 - mean_absolute_error: 0.8740
# Epoch 17/150
# 16438/16438 [==============================] - 2s 140us/step - loss: 3.2771 - mean_absolute_error: 0.8513
# Epoch 18/150
# 16438/16438 [==============================] - 3s 153us/step - loss: 3.0976 - mean_absolute_error: 0.8258
# Epoch 19/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 3.3204 - mean_absolute_error: 0.8143
# Epoch 20/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 3.0626 - mean_absolute_error: 0.8132
# Epoch 21/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.9995 - mean_absolute_error: 0.8221
# Epoch 22/150
# 16438/16438 [==============================] - 2s 150us/step - loss: 2.9888 - mean_absolute_error: 0.8268
# Epoch 23/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 3.0200 - mean_absolute_error: 0.8306
# Epoch 24/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.9523 - mean_absolute_error: 0.8321
# Epoch 25/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.8922 - mean_absolute_error: 0.7909
# Epoch 26/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.8890 - mean_absolute_error: 0.7358
# Epoch 27/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.8502 - mean_absolute_error: 0.7391
# Epoch 28/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.8908 - mean_absolute_error: 0.7776
# Epoch 29/150
# 16438/16438 [==============================] - 3s 152us/step - loss: 2.8520 - mean_absolute_error: 0.7517
# Epoch 30/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.8767 - mean_absolute_error: 0.7702
# Epoch 31/150
# 16438/16438 [==============================] - 3s 154us/step - loss: 2.8861 - mean_absolute_error: 0.7641
# Epoch 32/150
# 16438/16438 [==============================] - 2s 151us/step - loss: 2.7391 - mean_absolute_error: 0.7359
# Epoch 33/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.7419 - mean_absolute_error: 0.7300
# Epoch 34/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.7635 - mean_absolute_error: 0.7589
# Epoch 35/150
# 16438/16438 [==============================] - 3s 152us/step - loss: 2.6393 - mean_absolute_error: 0.7310
# Epoch 36/150
# 16438/16438 [==============================] - 2s 150us/step - loss: 2.7508 - mean_absolute_error: 0.7661
# Epoch 37/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.6365 - mean_absolute_error: 0.7572
# Epoch 38/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.6720 - mean_absolute_error: 0.7456
# Epoch 39/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.6019 - mean_absolute_error: 0.7353
# Epoch 40/150
# 16438/16438 [==============================] - 2s 141us/step - loss: 2.6091 - mean_absolute_error: 0.7291
# Epoch 41/150
# 16438/16438 [==============================] - 2s 142us/step - loss: 2.6840 - mean_absolute_error: 0.6963
# Epoch 42/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.7323 - mean_absolute_error: 0.7436
# Epoch 43/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.5463 - mean_absolute_error: 0.7169
# Epoch 44/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.6556 - mean_absolute_error: 0.7395
# Epoch 45/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.7199 - mean_absolute_error: 0.7178
# Epoch 46/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4700 - mean_absolute_error: 0.6995
# Epoch 47/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.5258 - mean_absolute_error: 0.7063
# Epoch 48/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.5876 - mean_absolute_error: 0.7353
# Epoch 49/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.6030 - mean_absolute_error: 0.7367
# Epoch 50/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.5038 - mean_absolute_error: 0.7074
# Epoch 51/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4802 - mean_absolute_error: 0.7123
# Epoch 52/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.5112 - mean_absolute_error: 0.6809
# Epoch 53/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4422 - mean_absolute_error: 0.6792
# Epoch 54/150
# 16438/16438 [==============================] - 2s 141us/step - loss: 2.4891 - mean_absolute_error: 0.7022
# Epoch 55/150
# 16438/16438 [==============================] - 2s 141us/step - loss: 2.7488 - mean_absolute_error: 0.7256
# Epoch 56/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.5908 - mean_absolute_error: 0.7002
# Epoch 57/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.4859 - mean_absolute_error: 0.6798
# Epoch 58/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4926 - mean_absolute_error: 0.6738
# Epoch 59/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.5947 - mean_absolute_error: 0.7103
# Epoch 60/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4334 - mean_absolute_error: 0.6825
# Epoch 61/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.5349 - mean_absolute_error: 0.6905
# Epoch 62/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.4619 - mean_absolute_error: 0.6727
# Epoch 63/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.4736 - mean_absolute_error: 0.6780
# Epoch 64/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.4587 - mean_absolute_error: 0.6827
# Epoch 65/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3770 - mean_absolute_error: 0.6924
# Epoch 66/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.5073 - mean_absolute_error: 0.6882
# Epoch 67/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.4810 - mean_absolute_error: 0.6847
# Epoch 68/150
# 16438/16438 [==============================] - 2s 150us/step - loss: 2.6391 - mean_absolute_error: 0.6802
# Epoch 69/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.5342 - mean_absolute_error: 0.7298
# Epoch 70/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.3693 - mean_absolute_error: 0.6485
# Epoch 71/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.4132 - mean_absolute_error: 0.6622
# Epoch 72/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.3833 - mean_absolute_error: 0.6602
# Epoch 73/150
# 16438/16438 [==============================] - 2s 150us/step - loss: 2.4819 - mean_absolute_error: 0.6833
# Epoch 74/150
# 16438/16438 [==============================] - 3s 153us/step - loss: 2.3935 - mean_absolute_error: 0.6855
# Epoch 75/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4840 - mean_absolute_error: 0.6816
# Epoch 76/150
# 16438/16438 [==============================] - 2s 141us/step - loss: 2.4615 - mean_absolute_error: 0.6535
# Epoch 77/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.2999 - mean_absolute_error: 0.6495
# Epoch 78/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3535 - mean_absolute_error: 0.6722
# Epoch 79/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.4924 - mean_absolute_error: 0.6882
# Epoch 80/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4441 - mean_absolute_error: 0.6563
# Epoch 81/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.3555 - mean_absolute_error: 0.6884
# Epoch 82/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.6036 - mean_absolute_error: 0.7146
# Epoch 83/150
# 16438/16438 [==============================] - 2s 139us/step - loss: 2.2951 - mean_absolute_error: 0.6602
# Epoch 84/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3757 - mean_absolute_error: 0.6939
# Epoch 85/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4539 - mean_absolute_error: 0.6708
# Epoch 86/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.5073 - mean_absolute_error: 0.6771
# Epoch 87/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4997 - mean_absolute_error: 0.6938
# Epoch 88/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3547 - mean_absolute_error: 0.6768
# Epoch 89/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.4614 - mean_absolute_error: 0.6753
# Epoch 90/150
# 16438/16438 [==============================] - 2s 142us/step - loss: 2.2627 - mean_absolute_error: 0.6508
# Epoch 91/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.4050 - mean_absolute_error: 0.6741
# Epoch 92/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.5832 - mean_absolute_error: 0.6803
# Epoch 93/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3581 - mean_absolute_error: 0.6590
# Epoch 94/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.4326 - mean_absolute_error: 0.6953
# Epoch 95/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.3513 - mean_absolute_error: 0.6733
# Epoch 96/150
# 16438/16438 [==============================] - 3s 156us/step - loss: 2.5150 - mean_absolute_error: 0.6551
# Epoch 97/150
# 16438/16438 [==============================] - 3s 160us/step - loss: 2.3492 - mean_absolute_error: 0.6891
# Epoch 98/150
# 16438/16438 [==============================] - 3s 158us/step - loss: 2.4403 - mean_absolute_error: 0.6981
# Epoch 99/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3100 - mean_absolute_error: 0.6460
# Epoch 100/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.2691 - mean_absolute_error: 0.6479
# Epoch 101/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.3321 - mean_absolute_error: 0.6771
# Epoch 102/150
# 16438/16438 [==============================] - 2s 141us/step - loss: 2.4215 - mean_absolute_error: 0.6700
# Epoch 103/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.4339 - mean_absolute_error: 0.6717
# Epoch 104/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.2548 - mean_absolute_error: 0.6571
# Epoch 105/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.4765 - mean_absolute_error: 0.6827
# Epoch 106/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.2630 - mean_absolute_error: 0.6695
# Epoch 107/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.7110 - mean_absolute_error: 0.6780
# Epoch 108/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.2962 - mean_absolute_error: 0.6591
# Epoch 109/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4910 - mean_absolute_error: 0.6780
# Epoch 110/150
# 16438/16438 [==============================] - 3s 159us/step - loss: 2.2944 - mean_absolute_error: 0.6460
# Epoch 111/150
# 16438/16438 [==============================] - 3s 160us/step - loss: 2.3274 - mean_absolute_error: 0.6737
# Epoch 112/150
# 16438/16438 [==============================] - 3s 157us/step - loss: 2.3099 - mean_absolute_error: 0.6494
# Epoch 113/150
# 16438/16438 [==============================] - 3s 157us/step - loss: 2.5870 - mean_absolute_error: 0.6858
# Epoch 114/150
# 16438/16438 [==============================] - 2s 142us/step - loss: 2.1791 - mean_absolute_error: 0.6403
# Epoch 115/150
# 16438/16438 [==============================] - 2s 142us/step - loss: 2.3405 - mean_absolute_error: 0.6677
# Epoch 116/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3381 - mean_absolute_error: 0.6506
# Epoch 117/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.2991 - mean_absolute_error: 0.6416
# Epoch 118/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.3504 - mean_absolute_error: 0.6642
# Epoch 119/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.4387 - mean_absolute_error: 0.6753
# Epoch 120/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.2502 - mean_absolute_error: 0.6653
# Epoch 121/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.2503 - mean_absolute_error: 0.6455
# Epoch 122/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3613 - mean_absolute_error: 0.6529
# Epoch 123/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.3234 - mean_absolute_error: 0.6519
# Epoch 124/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.1683 - mean_absolute_error: 0.6549
# Epoch 125/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.2833 - mean_absolute_error: 0.6561
# Epoch 126/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.4218 - mean_absolute_error: 0.6735
# Epoch 127/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.3391 - mean_absolute_error: 0.6631
# Epoch 128/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3325 - mean_absolute_error: 0.6438
# Epoch 129/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.2529 - mean_absolute_error: 0.6413
# Epoch 130/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3406 - mean_absolute_error: 0.6553
# Epoch 131/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.3421 - mean_absolute_error: 0.6190
# Epoch 132/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.2425 - mean_absolute_error: 0.6413
# Epoch 133/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.2915 - mean_absolute_error: 0.6478
# Epoch 134/150
# 16438/16438 [==============================] - 2s 143us/step - loss: 2.2800 - mean_absolute_error: 0.6391
# Epoch 135/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.3558 - mean_absolute_error: 0.6613
# Epoch 136/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3818 - mean_absolute_error: 0.6244
# Epoch 137/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.2394 - mean_absolute_error: 0.6511
# Epoch 138/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.2549 - mean_absolute_error: 0.6564
# Epoch 139/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.3796 - mean_absolute_error: 0.6500
# Epoch 140/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.4135 - mean_absolute_error: 0.6535
# Epoch 141/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.2723 - mean_absolute_error: 0.6530
# Epoch 142/150
# 16438/16438 [==============================] - 2s 145us/step - loss: 2.2610 - mean_absolute_error: 0.6549
# Epoch 143/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.3487 - mean_absolute_error: 0.6645
# Epoch 144/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.2582 - mean_absolute_error: 0.6480
# Epoch 145/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.3646 - mean_absolute_error: 0.6532
# Epoch 146/150
# 16438/16438 [==============================] - 2s 144us/step - loss: 2.2814 - mean_absolute_error: 0.6540
# Epoch 147/150
# 16438/16438 [==============================] - 2s 147us/step - loss: 2.2918 - mean_absolute_error: 0.6483
# Epoch 148/150
# 16438/16438 [==============================] - 2s 146us/step - loss: 2.2509 - mean_absolute_error: 0.6532
# Epoch 149/150
# 16438/16438 [==============================] - 2s 149us/step - loss: 2.3202 - mean_absolute_error: 0.6464
# Epoch 150/150
# 16438/16438 [==============================] - 2s 148us/step - loss: 2.2959 - mean_absolute_error: 0.6575

# %% [markdown]
# ### 3.2.2신경망 모델 저장.

# %%
filename = 'model/spend_rg_model.sav'
joblib.dump(model_as, filename)
# Out:
# ['/content/drive/My Drive/spend_rg_model.sav']
